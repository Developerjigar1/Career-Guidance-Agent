# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("../data/row_data/career_dataset.csv")

# %%
df["combined"] = df["skills"] + " " + df["interest"] # Combine relevant text columns

# %%
user_skills = input("Enter your skills: ")
user_interest = input("Enter your interest: ")

user_text = user_skills + " " + user_interest

# %%
vectorizer = TfidfVectorizer() # Initialize TF-IDF Vectorizer
tfidf_matrix = vectorizer.fit_transform(df["combined"])

user_vector = vectorizer.transform([user_text])

# %%
similarity_scores = cosine_similarity(user_vector, tfidf_matrix) # Compute cosine similarity

# %%
best_match_index = similarity_scores.argmax() # Get index of best match
recommended_career = df.iloc[best_match_index]["career"]

print(" Recommended Career:", recommended_career)
# Out:
#  Recommended Career: Software Developer
